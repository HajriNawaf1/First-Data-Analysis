# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
! ls
# Out:
# TEst.ipynb             patients.csv           titanic.csv
# Untitled3.ipynb        python 2020-2021.ipynb

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfc = df.copy()

# %%
dfc.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dfc.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dfc.rename({"PassengerId": "A"}, axis = 1 )
# Out:
#        A  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfc.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns.shape[0]
# Out:
# 12

# %%
dfc.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# ...

# %%
dfc.sort_index(axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dfc.sort_values('Name' , inplace = True)

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
dfc[0:]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 845          846         0       3                    Abbing, Mr. Anthony
# 746          747         0       3            Abbott, Mr. Rossmore Edward
# 279          280         1       3       Abbott, Mrs. Stanton (Rosa Hunt)
# 308          309         0       2                    Abelson, Mr. Samuel
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# ..           ...       ...     ...                                    ...
# 286          287         1       3                de Mulder, Mr. Theodore
# 282          283         0       3              de Pelsmaeker, Mr. Alfons
# 361          362         0       2              del Carlo, Mr. Sebastiano
# 153          154         0       3        van Billiard, Mr. Austin Blyler
# 868          869         0       3            van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# ...

# %%
pd.set_option('display.max_rows' ,dfc.shape[0]+1)
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 730          731         1       1
# 4              5         0       3
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
# 192          193         1       3
# 460          461         1       1
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# ...

# %%
dfc.reset_index(drop=True )
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 845          846         0       3
# 746          747         0       3
# 279          280         1       3
# 308          309         0       2
# 874          875         1       2
# 365          366         0       3
# 401          402         0       3
# 40            41         0       3
# 855          856         1       3
# 207          208         1       3
# 810          811         0       3
# 840          841         0       3
# 210          211         0       3
# 784          785         0       3
# 730          731         1       1
# 4              5         0       3
# 305          306         1       1
# 297          298         0       1
# 498          499         0       1
# 834          835         0       3
# 192          193         1       3
# 460          461         1       1
# 850          851         0       3
# 813          814         0       3
# 119          120         0       3
# ...

# %%
dfc.iloc [0:2, 4:6]
# Out:
#                           Name   Sex
# 0          Abbing, Mr. Anthony  male
# 1  Abbott, Mr. Rossmore Edward  male

# %%
dfc.reset_index(inplace= True)

# %%
dfc.drop('index', axis = 1 , inplace = True)

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 0            846         0       3
# 1            747         0       3
# 2            280         1       3
# 3            309         0       2
# 4            875         1       2
# 5            366         0       3
# 6            402         0       3
# 7             41         0       3
# 8            856         1       3
# 9            208         1       3
# 10           811         0       3
# 11           841         0       3
# 12           211         0       3
# 13           785         0       3
# 14           731         1       1
# 15             5         0       3
# 16           306         1       1
# 17           298         0       1
# 18           499         0       1
# 19           835         0       3
# 20           193         1       3
# 21           461         1       1
# 22           851         0       3
# 23           814         0       3
# 24           120         0       3
# ...

# %%
dfc.at[: , 'Pclass']= np.array([3] * len(dfc))

# %%
len(dfc)
# Out:
# 891

# %%
np.array([5])

# %%
dfc
# Out:
#      PassengerId  Survived  Pclass  \
# 0            846         0       3
# 1            747         0       3
# 2            280         1       3
# 3            309         0       3
# 4            875         1       3
# 5            366         0       3
# 6            402         0       3
# 7             41         0       3
# 8            856         1       3
# 9            208         1       3
# 10           811         0       3
# 11           841         0       3
# 12           211         0       3
# 13           785         0       3
# 14           731         1       3
# 15             5         0       3
# 16           306         1       3
# 17           298         0       3
# 18           499         0       3
# 19           835         0       3
# 20           193         1       3
# 21           461         1       3
# 22           851         0       3
# 23           814         0       3
# 24           120         0       3
# ...

# %%
dfc.dropna(how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 14           731         1       3
# 16           306         1       3
# 17           298         0       3
# 18           499         0       3
# 21           461         1       3
# 33           276         1       3
# 34           807         0       3
# 36           572         1       3
# 45           701         1       3
# 48           370         1       3
# 60           328         1       3
# 66           631         1       3
# 70           119         0       3
# 71           300         1       3
# 72           219         1       3
# 76           184         1       3
# 77           619         1       3
# 78           249         1       3
# 79           872         1       3
# 80            22         1       3
# 81           890         1       3
# 89           485         1       3
# 90           292         1       3
# 91           270         1       3
# 92           431         1       3
# ...

# %%
df1=df.copy()

# %%
dfc.fillna(value = 0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            846         0       3
# 1            747         0       3
# 2            280         1       3
# 3            309         0       3
# 4            875         1       3
# 5            366         0       3
# 6            402         0       3
# 7             41         0       3
# 8            856         1       3
# 9            208         1       3
# 10           811         0       3
# 11           841         0       3
# 12           211         0       3
# 13           785         0       3
# 14           731         1       3
# 15             5         0       3
# 16           306         1       3
# 17           298         0       3
# 18           499         0       3
# 19           835         0       3
# 20           193         1       3
# 21           461         1       3
# 22           851         0       3
# 23           814         0       3
# 24           120         0       3
# ...

# %%
# Out:
#   File "<ipython-input-144-0901725dd0a1>", line 1
#     for i == True in dfc.isna() :
#            ^
# SyntaxError: invalid syntax

# %%
dfc.drop('Cabin',axis=1,inplace=True)

# %%
dfc.mean(1)
# Out:
# 0      123.078571
# 1      111.035714
# 2       44.464286
# 3       48.857143
# 4      129.857143
# 5       54.464286
# 6       59.721429
# 7        8.496429
# 8      125.050000
# 9       33.683929
# 10     118.126786
# 11     122.417857
# 12      32.292857
# 13     114.292857
# 14     135.905357
# 15       3.007143
# 16      67.078571
# 17      65.792857
# 18      94.507143
# 19     121.614286
# 20      30.122029
# 21      70.935714
# 22     128.039286
# 23     122.753571
# 24      23.610714
# 25      13.132143
# 26      83.896429
# 27      84.039286
# 28       8.467857
# 29      23.399400
# 30      93.753571
# 31      15.407743
# 32      23.500000
# 33      51.994043
# 34     116.428571
# 35      79.285714
# 36      90.639886
# 37      54.400000
# 38      10.971429
# 39      78.786314
# 40      54.150000
# 41      32.626786
# 42      44.055357
# 43      40.055357
# 44      10.341071
# 45     134.075000
# 46      19.636900
# 47      37.175000
# 48      64.042857
# 49     121.407743
# ...

# %%
dfc.groupby('Sex')['Age'].value_counts()
# Out:
# Sex     Age
# female  5      314
# male    5      577
# Name: Age, dtype: int64

# %%
usex = df['Sex'].unique()

# %%
usex
# Out:
# array(['male', 'female'], dtype=object)

# %%
dfc['Pclass'] = dfc['Pclass'].replace({3:'First Class'})

# %%
for i in range(len(dfc)):
    dfc['PassengerId'] = dfc['PassengerId'].replace({dfc.iat[i:,"PassengerId"] :i})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-83a4e924412f> in <module>
#       1 for i in range(len(dfc)):
# ----> 2     dfc['PassengerId'] = dfc['PassengerId'].replace({dfc.iat[i:,"PassengerId"] :i})
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2175                 raise ValueError("Invalid call for scalar access (getting)!")
#    2176
# -> 2177         key = self._convert_key(key)
#    2178         return self.obj._get_value(*key, takeable=self._takeable)
#    2179
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_key(self, key, is_setter)
#    2234         for a, i in zip(self.obj.axes, key):
#    2235             if not is_integer(i):
# -> 2236                 raise ValueError("iAt based indexing can only have integer indexers")
#    2237         return key
# ...

# %%
# Out:
# 891

# %%
dfc['Pclass'].str.upper()
# Out:
# 0      FIRST CLASS
# 1      FIRST CLASS
# 2      FIRST CLASS
# 3      FIRST CLASS
# 4      FIRST CLASS
# 5      FIRST CLASS
# 6      FIRST CLASS
# 7      FIRST CLASS
# 8      FIRST CLASS
# 9      FIRST CLASS
# 10     FIRST CLASS
# 11     FIRST CLASS
# 12     FIRST CLASS
# 13     FIRST CLASS
# 14     FIRST CLASS
# 15     FIRST CLASS
# 16     FIRST CLASS
# 17     FIRST CLASS
# 18     FIRST CLASS
# 19     FIRST CLASS
# 20     FIRST CLASS
# 21     FIRST CLASS
# 22     FIRST CLASS
# 23     FIRST CLASS
# 24     FIRST CLASS
# 25     FIRST CLASS
# 26     FIRST CLASS
# 27     FIRST CLASS
# 28     FIRST CLASS
# 29     FIRST CLASS
# 30     FIRST CLASS
# 31     FIRST CLASS
# 32     FIRST CLASS
# 33     FIRST CLASS
# 34     FIRST CLASS
# 35     FIRST CLASS
# 36     FIRST CLASS
# 37     FIRST CLASS
# 38     FIRST CLASS
# 39     FIRST CLASS
# 40     FIRST CLASS
# 41     FIRST CLASS
# 42     FIRST CLASS
# 43     FIRST CLASS
# 44     FIRST CLASS
# 45     FIRST CLASS
# 46     FIRST CLASS
# ...

# %%
df1.groupby('Sex')['Age'].value_counts()
# Out:
# Sex     Age
# female  24.00    16
#         18.00    13
#         22.00    12
#         30.00    11
#         35.00     8
#         19.00     7
#         21.00     7
#         28.00     7
#         29.00     7
#         31.00     7
#         36.00     7
#         2.00      6
#         16.00     6
#         17.00     6
#         27.00     6
#         33.00     6
#         39.00     6
#         40.00     6
#         45.00     6
#         4.00      5
#         23.00     5
#         25.00     5
#         38.00     5
#         50.00     5
#         5.00      4
#         9.00      4
#         14.00     4
#         15.00     4
#         26.00     4
#         34.00     4
#         41.00     4
#         48.00     4
#         32.00     3
#         42.00     3
#         44.00     3
#         54.00     3
#         58.00     3
#         0.75      2
#         1.00      2
#         3.00      2
#         6.00      2
#         8.00      2
#         13.00     2
#         20.00     2
# ...

# %%
df["Age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 27.00    18
# 32.00    18
# 35.00    18
# 16.00    17
# 31.00    17
# 26.00    17
# 23.00    15
# 34.00    15
# 33.00    15
# 20.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 4.00     10
# 2.00     10
# 47.00     9
# 48.00     9
# 44.00     9
# 54.00     8
# 9.00      8
# 51.00     7
# 1.00      7
# 52.00     6
# 3.00      6
# 49.00     6
# 41.00     6
# 37.00     6
# 14.00     6
# 58.00     5
# 43.00     5
# 15.00     5
# 60.00     4
# 62.00     4
# 8.00      4
# 56.00     4
# 5.00      4
# 11.00     4
# 46.00     3
# 65.00     3
# 7.00      3
# 6.00      3
# 61.00     3
# 28.50     2
# 55.00     2
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 64.00     2
# 10.00     2
# 13.00     2
# 45.50     2
# 40.50     2
# ...

# %%
dfc.plot()
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.close('all')

# %%
df.plot()

# %%
dfc.hist(figsize=(20,15) , bins=20)
plt.show()

# %%
dfc['Survived']=dfc['Survived'].replace({0:'Live' , 1:'Death'})

# %%
dfc
# Out:
#      PassengerId Survived       Pclass  \
# 0            846     Live  First Class
# 1            747     Live  First Class
# 2            280    Death  First Class
# 3            309     Live  First Class
# 4            875    Death  First Class
# 5            366     Live  First Class
# 6            402     Live  First Class
# 7             41     Live  First Class
# 8            856    Death  First Class
# 9            208    Death  First Class
# 10           811     Live  First Class
# 11           841     Live  First Class
# 12           211     Live  First Class
# 13           785     Live  First Class
# 14           731    Death  First Class
# 15             5     Live  First Class
# 16           306    Death  First Class
# 17           298     Live  First Class
# 18           499     Live  First Class
# 19           835     Live  First Class
# 20           193    Death  First Class
# 21           461    Death  First Class
# 22           851     Live  First Class
# ...

# %%
dfv = dfc.pivot_table(index = ['Survived'], aggfunc ='size') 
dfv
# Out:
# Survived
# Death    342
# Live     549
# dtype: int64

# %%
dfc.to_excel('Test.xlsx')

# %%
! ls
# Out:
# TEst.ipynb             Untitled3.ipynb        python 2020-2021.ipynb
# Test.xlsx              patients.csv           titanic.csv
